# %%
import os
import sys
os.path.dirname(sys.executable)
# Out:
# 'c:\\Users\\Abdul\\Anaconda3'

# %%
# to transfer arabic number to english 
import pyarabic.trans

# %%
import pandas as pd
import numpy as np
import tabula

# %%
# # convert PDF into CSV file
tabula.convert_into("../data/StudentGPA.pdf", "../data/StudentGPA.csv", output_format="csv", pages='all')

# %%
# with open("../data/StudentGPA", "r+" , encoding="utf8") as f:
#     d = f.readlines()
#     f.seek(0)
#     for i in d:
#         if i != '"'[0]:
#             print(i[1])
#             # f.write(i)
#     # f.truncate()

# %%
df = pd.read_csv('../data/StudentGPA.csv',  on_bad_lines='skip')

# %%
# '\"\",,,,,,' == "",,,,,,

# %% [markdown]
# # i don't know why it is not reading the Primary Year

# %%
df
# Out:
#     التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 0       NaN     NaN        3                         تقنیات الویب      CS 471
# 1       NaN     NaN        3                  مقدمة في أمن الحاسب      CS 451
# 2       NaN     NaN        3                  المعادلات التفاضلیة     MATH218
# 3       NaN     NaN        3                          برمجة النظم      CS 423
# 4       NaN     NaN        2                       مشروع تخرج (1)      CS 498
# 5   التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 6        ب+     4.5        1                    معمل شبكات الحاسب     COE 352
# 7         أ   14.25        3                              التشفیر      CS 452
# 8         أ   14.25        3                     تقنیات الأمثلیات      CS 348
# 9   التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 10        ب      12        3                         شبكات الحاسب     COE 351
# 11       أ+      15        3                 ریاضیات محددة متقدمة     MATH314
# 12       أ+      15        3                مقدمة في الحاسب الآلي      CS 101
# 13  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 14       ب+    13.5        3                        بحوث العملیات     MATH329
# 15       أ+      15        3                 اللغة الإنجلیزیة (1)     ENG 101
# 16       ب+       9        2        أسس النظام السیاسي في الإسلام      IC 104
# 17       ب+    13.5        3                        الطرق العددیة     MATH317
# 18        ج       9        3                      البرمجة المرئیة      CS 342
# 19       ب+    13.5        3                        الرسم بالحاسب      CS 341
# 20  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 21       ب+    13.5        3                      ھندسة البرمجیات      CS 383
# 22        أ   14.25        3             تحلیل وتصمیم الخوارزمیات      CS 315
# 23  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 24       ج+    10.5        3                          لغة التجمیع      CS 221
# 25       ب+    13.5        3                         نظام التشغیل      CS 222
# 26       أ+      15        3                      تصمیم المترجمات      CS 224
# 27       ب+       9        2      مھارات الإتصال وأخلاقیات المھنة      IT 362
# 28        ب      12        3                      تراكیب البیانات      CS 214
# 29       أ+      10        2                الإسلام وبناء المجتمع      IC 102
# 30  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 31       ب+       9        2          النظام الاقتصادي في الإسلام      IC 103
# 32        أ   14.25        3                   مبادئ لغات البرمجة      CS 213
# 33        أ   14.25        3                         عمارة الحاسب     COE 223
# 34        ب      12        3         علم البیانات لإنترنت الاشیاء      IT 351
# 35       ب+    13.5        3                   مفاھیم الخوارزمیات      CS 211
# 36        ب      12        3                        ریاضیات محددة     MATH212
# 37  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 38       أ+      10        2                       التحریر العربي     ARAB103
# 39       أ+      15        3                     برمجة الحاسب (3)      CS 182
# 40        أ   14.25        3                  الإحصاء والإحتمالات     STAT126
# 41        أ    4.75        1               التصمیم المنطقي )معمل(     COE 122
# 42       أ+      15        3  الجبر الخطي والحساب متعدد المتغیرات     MATH116
# 43       أ+      15        3                      التصمیم المنطقي     COE 121
# 44  التقدیر  النقاط  الساعات                           اسم المقرر  رمز المقرر
# 45       أ+      15        3                         حساب التكامل     MATH115
# 46       أ+      15        3                     برمجة الحاسب (2)      CS 181
# 47        أ      19        4                      فیزیاء عامھ (3)     PHYS116
# 48        ب       8        2                     المھارات اللغویة     ARAB101
# 49       ب+       9        2         المدخل إلى الثقافة الإسلامیة      IC 101
# 50       ب+    13.5        3                         قواعد بیانات      IT 131

# %%
df = df[df['رمز المقرر'] !='رمز المقرر' ]

# %%
df["الساعات"] = df["الساعات"].astype(int)
# Out:
# C:\Users\Abdul\AppData\Local\Temp\ipykernel_7576\3146702888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["الساعات"] = df["الساعات"].astype(int)

# %% [markdown]
# ## thus it give me that i only have 118 hours

# %%
df["الساعات"].sum()
# Out:
# 118

# %%
for ind , row in df.iterrows() :
    for i in df.columns :
        try:
            df[i][ind] = pyarabic.trans.normalize_digits(row[i])
        except:
            pass
# Out:
# C:\Users\Abdul\AppData\Local\Temp\ipykernel_7576\3638602769.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i][ind] = pyarabic.trans.normalize_digits(row[i])

# %%
df.to_csv('../data/StudentGPA.csv' , index=False)
